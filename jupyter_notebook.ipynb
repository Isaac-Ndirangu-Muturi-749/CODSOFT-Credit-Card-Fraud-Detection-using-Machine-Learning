# %% [markdown]
# Follow me on Twitter 🐦, connect with me on LinkedIn 🔗, and check out my GitHub 🐙. You won't be disappointed!
#
# 👉 Twitter: https://twitter.com/NdiranguMuturi1
# 👉 LinkedIn: https://www.linkedin.com/in/isaac-muturi-3b6b2b237
# 👉 GitHub: https://github.com/Isaac-Ndirangu-Muturi-749

# %% [markdown]
# # Credit Card Fraud Detection with Machine Learning: Enhancing Financial Security

# %% [markdown]
# ![creditcardfraud](creditcardfraud.png)

# %% [markdown]
# # BUSINESS UNDERSTANDING
#
# ## Introduction
#
# Credit card fraud poses a significant threat to financial institutions and their customers. As fraudulent activities continue to evolve and become more sophisticated, it is imperative for financial organizations to employ advanced techniques to detect and prevent fraudulent transactions. This project aims to address the critical business challenge of identifying fraudulent credit card transactions accurately.
#
# ## Problem Statement
#
# The primary objective of this project is to develop an effective fraud detection system that can automatically identify suspicious or fraudulent credit card transactions in real-time. The system needs to strike a balance between minimizing false positives (genuine transactions incorrectly flagged as fraudulent) and detecting as many fraudulent transactions as possible.
#
# ## Business Impact
#
# Effective fraud detection has several crucial business implications:
#
# 1. **Risk Mitigation**: Fraudulent transactions can result in substantial financial losses for both financial institutions and customers. Accurate fraud detection helps mitigate these risks and protect financial assets.
#
# 2. **Customer Trust**: Timely detection and prevention of fraud enhance customer trust. Customers are more likely to remain loyal to a financial institution that provides secure and reliable services.
#
# 3. **Operational Efficiency**: Automating the fraud detection process reduces the need for manual intervention, leading to cost savings and operational efficiency.
#
# 4. **Compliance**: Regulatory bodies often require financial institutions to have robust fraud prevention measures in place. Non-compliance can lead to legal and financial penalties.
#
# ## Data Availability
#
# To address the business challenge of credit card fraud detection, we have access to historical credit card transaction data. This dataset includes information about various transaction attributes, such as transaction amount, merchant information, and anonymized customer features.
#
# ## Approach
#
# Our approach involves leveraging machine learning techniques to build and train models capable of distinguishing between legitimate and fraudulent transactions. We will explore different algorithms, feature engineering, and model evaluation methods to optimize fraud detection accuracy.
#
# ## Key Metrics
#
# To measure the success of our fraud detection system, we will focus on the following key metrics:
#
# - **False Positive Rate (FPR)**: The proportion of genuine transactions incorrectly flagged as fraudulent. Lower FPR indicates a more effective system.
#
# - **True Positive Rate (TPR)**: The proportion of fraudulent transactions correctly identified as such. Higher TPR signifies better fraud detection.
#
# - **Precision**: The ratio of true positive predictions to the total positive predictions. High precision indicates fewer false positives.
#
# - **F1 Score**: A metric that balances precision and recall. It provides a single value to assess model performance.
#
# ## Project Goals
#
# Our project goals are as follows:
#
# 1. Develop and deploy a fraud detection system capable of real-time monitoring of credit card transactions.
#
# 2. Achieve a high level of accuracy in identifying fraudulent transactions while minimizing false positives.
#
# 3. Continuously monitor and update the system to adapt to evolving fraud patterns.
#
# By achieving these goals, we aim to enhance the security of credit card transactions, reduce financial losses due to fraud, and maintain customer trust.

# %% [markdown]
# # DATA UNDERSTANDING
#
# # Dataset Analyzer
#
# This class, `DatasetAnalyzer`, is designed to analyze a dataset related to banking. It provides various methods to gather insights about the dataset, identify patterns, and address data quality issues. This class is part of a broader data analysis and preprocessing process.
#
# ## How It Works
#
# ### Initialization
#
# 1. Import the necessary libraries: `pandas`, `matplotlib.pyplot`, `seaborn`, and `numpy`.
#
# 2. Define a class named `DatasetAnalyzer` that takes the path to the dataset as a parameter during initialization (`dataset_path`).
#
# 3. Inside the `__init__` method, the dataset is loaded using `pd.read_csv()` and stored as an attribute (`self.dataset`).
#
# ### Data Exploration and Analysis Methods
#
# The class provides several methods to explore and analyze the dataset:
#
# - `preview_dataset(num_rows)`: Displays the first and last few rows of the dataset.
#
# - `check_columns_list()`: Returns a list of columns in the dataset.
#
# - `explore_column_value_counts()`: Prints the value counts for each column in the dataset.
#
# - `get_dataset_shape()`: Returns the number of rows and columns in the dataset.
#
# - `get_dataset_info()`: Displays information about the dataset, including data types and memory usage.
#
# - `get_dataset_description()`: Provides a statistical description of the dataset, including measures like mean, min, max, and quartiles.
#
# - `analyze_duplicated_rows()`: Counts and visualizes the percentage of duplicated rows in the dataset.
#
# - `analyze_missing_values()`: Counts and visualizes the percentage of missing values for each column in the dataset.
#
# - `count_data_types()`: Returns the count of data types present in the dataset.
#
# - `count_unique_values_by_dtype()`: Counts and prints the number of unique values for integer, float, and object columns.
#
# Each method is designed to provide insights into different aspects of the dataset, helping to identify data quality issues, patterns, and trends.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

class DatasetAnalyzer:
    def __init__(self, dataset_path, delimiter=',', encoding='utf-8'):
        # Initialize the DatasetAnalyzer with the dataset path, delimiter, and encoding
        self.dataset_path = dataset_path
        self.delimiter = delimiter
        self.encoding = encoding
        self.dataset = pd.read_csv(dataset_path, delimiter=self.delimiter, encoding=self.encoding)

    def preview_dataset(self, num_rows=5):
        # Display the first few and last few rows of the dataset
        print(f"Preview of the dataset (first {num_rows} rows):")
        print(self.dataset.head(num_rows))
        print(f"Preview of the dataset (last {num_rows} rows):")
        print(self.dataset.tail(num_rows))

    def check_columns_list(self):
        # Get the list of columns in the dataset
        return self.dataset.columns.tolist()

    def explore_column_value_counts(self):
        # Explore the value counts for each column
        column_value_counts = {}

        for column in self.dataset.columns:
            column_value_counts[column] = self.dataset[column].value_counts()

        for column, values in column_value_counts.items():
            print(f"Value Counts for Column '{column}':\n{values}\n")

    def get_dataset_shape(self):
        # Get the shape of the dataset
        return self.dataset.shape

    def get_dataset_info(self):
        # Get information about the dataset
        return self.dataset.info()

    def get_dataset_description(self):
        # Get a statistical description of the dataset
        return self.dataset.describe()

    def analyze_duplicated_rows(self):
        # Analyze duplicate rows
        duplicate_count = self.dataset.duplicated().sum()

        # Print duplicate rows count
        print("Duplicate Rows Count:", duplicate_count)

        # Calculate the percentage of duplicate rows
        duplicate_percentage = (duplicate_count / len(self.dataset)) * 100

        # Create a bar chart to visualize the percentage of duplicate rows
        plt.figure(figsize=(6, 4))
        sns.barplot(x=["Duplicate Rows", "Non-Duplicate Rows"],
                    y=[duplicate_percentage, 100 - duplicate_percentage], color='skyblue', edgecolor='black')
        plt.ylabel("Percentage (%)")
        plt.title("Percentage of Duplicated Rows")
        plt.tight_layout()
        plt.show()

    def analyze_missing_values(self):
        # Analyze missing values
        missing_values_count = self.dataset.isnull().sum()

        # Print missing values counts
        print("Missing Values Counts:")
        print(missing_values_count)

         # Calculate the percentage of missing values for each column
        missing_percentage = (self.dataset.isnull().sum() / len(self.dataset)) * 100

        # Create a bar chart to visualize the percentage of missing values
        plt.figure(figsize=(10, 6))
        sns.barplot(x=missing_percentage.index, y=missing_percentage.values, color='skyblue', edgecolor='black')
        plt.xlabel('Columns')
        plt.ylabel('Percentage of Missing Values')
        plt.title('Percentage of Missing Values in Each Column')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    def count_data_types(self):
        # Count the data types in the dataset
        return self.dataset.dtypes.value_counts()

    def count_unique_values_by_dtype(self):
         # Group columns by data type
        data_types = self.dataset.dtypes

        # Separate columns by data type
        int_columns = data_types[data_types == 'int64'].index
        float_columns = data_types[data_types == 'float64'].index
        object_columns = data_types[data_types == 'object'].index

        print("Unique Values Counts by Data Type:")

        # Print columns and their counts for each data type
        print("Integer Columns:")
        print(self.dataset[int_columns].nunique())

        print("\nFloat Columns:")
        print(self.dataset[float_columns].nunique())

        print("\nObject Columns:")
        print(self.dataset[object_columns].nunique())

# %%
# Create an instance of DatasetAnalyzer
analyzer = DatasetAnalyzer("data/creditcard.csv")

# %%
# Preview the dataset
analyzer.preview_dataset()
# Out:
# Preview of the dataset (first 5 rows):
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# ...

# %%
# Get the list of columns in the dataset
columns_list = analyzer.check_columns_list()
print("Columns in the dataset:", columns_list)
# Out:
# Columns in the dataset: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %%
# Explore value counts for each column
analyzer.explore_column_value_counts()
# Out:
# Value Counts for Column 'Time':
# 163152.0    36
# 64947.0     26
# 68780.0     25
# 3767.0      21
# 3770.0      20
#             ..
# 2088.0       1
# 64100.0      1
# 42068.0      1
# 119630.0     1
# 140344.0     1
# Name: Time, Length: 124592, dtype: int64
#
# Value Counts for Column 'V1':
#  2.055797    77
#  1.245674    77
#  2.053311    62
#  1.302378    60
#  2.040211    53
#              ..
# -0.069327     1
# -1.619420     1
#  1.174923     1
#  2.157306     1
#  2.287784     1
# Name: V1, Length: 275663, dtype: int64
#
# Value Counts for Column 'V2':
#  0.166975    77
# -0.326668    77
#  0.089735    62
# -0.606529    60
# -0.146975    53
#              ..
#  0.520114     1
# -0.419199     1
# -0.303794     1
#  0.167497     1
# -0.166213     1
# Name: V2, Length: 275663, dtype: int64
#
# Value Counts for Column 'V3':
# -2.752041    77
#  0.488306    77
# -1.681836    62
# -0.681986    60
# -2.955934    53
#              ..
# -2.773663     1
# -2.148874     1
# ...

# %%
# Get the shape of the dataset
dataset_shape = analyzer.get_dataset_shape()
print("Shape of the dataset:", dataset_shape)
# Out:
# Shape of the dataset: (284807, 31)

# %%
# Get information about the dataset
dataset_info = analyzer.get_dataset_info()
print("Information about the dataset:")
print(dataset_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Get a statistical description of the dataset
dataset_description = analyzer.get_dataset_description()
print("Statistical description of the dataset:")
print(dataset_description)
# Out:
# Statistical description of the dataset:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
# Analyze duplicate rows and visualize the percentage
analyzer.analyze_duplicated_rows()
# Out:
# Duplicate Rows Count: 1081

# %%
# Analyze missing values and visualize the percentage
analyzer.analyze_missing_values()
# Out:
# Missing Values Counts:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Count data types in the dataset
data_type_counts = analyzer.count_data_types()
print("Data types counts:")
print(data_type_counts)
# Out:
# Data types counts:
# float64    30
# int64       1
# dtype: int64

# %%
# Count unique values by data type
analyzer.count_unique_values_by_dtype()
# Out:
# Unique Values Counts by Data Type:
# Integer Columns:
# Class    2
# dtype: int64
#
# Float Columns:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# dtype: int64
#
# Object Columns:
# Series([], dtype: float64)

# %% [markdown]
# ## Dataset Understanding Summary
#
# Here is a concise summary of the key information about the dataset:
#
# ### General Information
#
# - The dataset contains a total of 284,807 rows and 31 columns.
# - The columns represent various features, including numerical features (e.g., 'Time', 'Amount', 'V1' to 'V28') and a binary classification target variable ('Class').
#
# ### Column Description
#
# - **Time**: Represents the time elapsed since the first transaction.
# - **Amount**: Indicates the transaction amount.
# - **V1** to **V28**: These are numerical features representing various aspects of the transactions. These features have been anonymized for security and privacy reasons.
# - **Class**: This binary column indicates whether a transaction is fraudulent (1) or not (0).
#
# ### Data Statistics
#
# - The dataset provides various statistics for each numerical column, including mean, standard deviation, minimum, maximum, and quartile values.
# - For the 'Class' column, it appears to be highly imbalanced, with a vast majority of non-fraudulent transactions (Class 0) and a small number of fraudulent transactions (Class 1).
#
# ### Data Quality
#
# - There are no missing values in any of the columns.
# - Duplicate rows have been identified in the dataset, with 1,081 duplicate rows present.
#
# ### Data Types
#
# - The majority of the columns are of the `float64` data type (30 columns).
# - The 'Class' column is of the `int64` data type (1 column).
#
# ### Value Counts
#
# - The 'Time' column contains a wide range of values with varying frequencies.
# - The 'Amount' column also varies in transaction amounts.
# - The 'Class' column shows a significant class imbalance with a large number of non-fraudulent transactions (Class 0) and a relatively small number of fraudulent transactions (Class 1).
#
# This dataset appears to be related to credit card transactions, with the goal likely being the detection of fraudulent transactions (Class 1). The class imbalance may require special attention when performing machine learning tasks on this dataset, such as classification.

# %%
df=analyzer.dataset

# %% [markdown]
# ## Correlation and Outlier Analysis
#
# ### Importing Libraries
# - The code starts by importing necessary libraries: `pandas` (imported as `pd`), `numpy` (imported as `np`), `matplotlib.pyplot` (imported as `plt`), and `seaborn` (imported as `sns`).
#
# ### CorrelationOutlierAnalyzer Class
# - The `CorrelationOutlierAnalyzer` class is defined to analyze the correlation and identify outliers in a given dataset.
#
# ### Initialization
# - The class constructor (`__init__`) takes a dataset as input and selects only numeric columns of type 'int64' and 'float64'.
#
# ### Method: plot_correlation_heatmap
# - `plot_correlation_heatmap` generates a correlation heatmap using Seaborn's `heatmap` function.
# - The correlation matrix is computed using `self.data.corr()`.
# - A triangular mask is created to hide the upper triangle of the heatmap (as it's symmetric).
# - The heatmap is displayed with annotated correlation values.
#
# ### Method: get_correlation_df
# - `get_correlation_df` calculates the absolute correlation between features and sorts them in descending order.
# - The correlation pairs are stored in a DataFrame and presented in a concise format.
# - The function returns the top 50 correlated feature pairs.
#
# ### Method: explore_outliers
# - `explore_outliers` generates box plots for each numeric column to visualize potential outliers.
# - Subplots are organized in a grid, with the number of rows determined by the number of columns.
# - Box plots display the distribution and potential outliers of each column.
# - Titles are assigned to each plot and x-axis labels are rotated if needed.
#
# The provided code defines a class that facilitates the analysis of correlations and the identification of potential outliers in a dataset using visualization techniques.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class CorrelationOutlierAnalyzer:
    def __init__(self, data):
        self.data = data.select_dtypes(include=['int64', 'float64'])

    def plot_correlation_heatmap(self):
        corr_mat = self.data.corr()
        mask = np.triu(np.ones_like(corr_mat, dtype=bool))
        plt.subplots(figsize=(15, 12))
        sns.heatmap(corr_mat, annot=True, cmap='Blues', square=True, fmt='.0g')
        plt.title("Correlation Heatmap of Features")
        plt.xticks(rotation=90)
        plt.yticks(rotation=0)
        plt.show()

    def get_correlation_df(self):
        corr_df = self.data.corr().abs().stack().reset_index().sort_values(0, ascending=False)
        corr_df['pairs'] = list(zip(corr_df.level_0, corr_df.level_1))
        corr_df.set_index(['pairs'], inplace=True)
        corr_df.drop(columns=['level_1', 'level_0'], inplace=True)
        corr_df.columns = ['cc']
        corr_df = corr_df.drop_duplicates()
        return corr_df.head(50)

    def explore_outliers(self):
        # Calculate the number of rows and columns for subplots
        num_cols = len(self.data.columns)
        num_rows = (num_cols - 1) // 2 + 1  # Divide by 2, rounded up

        # Create a grid of subplots
        fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(15, num_rows * 5))

        # Flatten the axes for easy iteration
        axes = axes.flatten()

        # Plot box plots for each column
        for i, col in enumerate(self.data.columns):
            sns.boxplot(data=self.data, y=col, ax=axes[i])
            axes[i].set_title(f"Box Plot of {col}")
            axes[i].set_ylabel("")  # Remove y-axis label to save space
            axes[i].set_xlabel("")  # Remove x-axis label
            axes[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels if needed

        plt.tight_layout()
        plt.show()

# Create an instance of CorrelationOutlierAnalyzer
data_analyzer = CorrelationOutlierAnalyzer(df)

# Plot correlation heatmap
data_analyzer.plot_correlation_heatmap()

# Get correlation dataframe
print(data_analyzer.get_correlation_df())

# Explore outliers using box plots
data_analyzer.explore_outliers()
# Out:
#                      cc
# pairs
# (Time, Time)   1.000000
# (Amount, V2)   0.531409
# (Time, V3)     0.419618
# (Amount, V7)   0.397311
# (V5, Amount)   0.386356
# (Amount, V20)  0.339403
# (V17, Class)   0.326481
# (Class, V14)   0.302544
# (Class, V12)   0.260593
# (Time, V11)    0.247689
# (V25, Time)    0.233083
# (V1, Amount)   0.227709
# (Class, V10)   0.216883
# (Amount, V6)   0.215981
# (V3, Amount)   0.210880
# (V16, Class)   0.196539
# (Class, V3)    0.192961
# (Class, V7)    0.187257
# (V15, Time)    0.183453
# (Time, V5)     0.173072
# (V11, Class)   0.154876
# (Time, V22)    0.144059
# (Class, V4)    0.133447
# (V12, Time)    0.124348
# (V1, Time)     0.117396
# (V23, Amount)  0.112633
# (V18, Class)   0.111485
# (V21, Amount)  0.105999
# (V4, Time)     0.105260
# (V8, Amount)   0.103079
# (V10, Amount)  0.101502
# (V1, Class)    0.101347
# (Time, V14)    0.098757
# (Amount, V4)   0.098732
# (V9, Class)    0.097733
# (V5, Class)    0.094974
# (Class, V2)    0.091289
# ...

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # DATA CLEANING

# %%
import pandas as pd

def remove_duplicates(df):
    # Print the number of rows before removing duplicates
    print(f"Number of rows before removing duplicates: {df.shape[0]}")
    
    # Remove duplicates and reset the index
    df = df.drop_duplicates().reset_index(drop=True)
    
    # Print the number of rows after removing duplicates
    print(f"Number of rows after removing duplicates: {df.shape[0]}")
    
    return df


df = remove_duplicates(df)
# Out:
# Number of rows before removing duplicates: 284807
# Number of rows after removing duplicates: 283726

# %% [markdown]
# ## EXPLOTARY DATA ANALYSIS(EDA)

# %% [markdown]
# # Univariate Data Visualization
#
# The `UnivariateVisualizer` class is designed to help visually explore the distribution of categorical and continuous variables in your dataset. This can provide insights into the characteristics of individual variables, their frequency distribution, and help identify potential trends or patterns.
#
# ## Usage
#
# To use the `UnivariateVisualizer`, follow these steps:
#
# 1. Instantiate the class with your dataset: `visualizer = UnivariateVisualizer(data)`.
# 2. Call the `plot_categorical_distribution()` method to visualize the distribution of categorical variables.
# 3. Call the `plot_continuous_distribution()` method to visualize the distribution of continuous variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

class UnivariateVisualizer:
    def __init__(self, data):
        self.data = data
        self.categorical_vars = self.data.select_dtypes(include=['object']).columns.tolist()
        self.continuous_vars = self.data.select_dtypes(include=['int64', 'float64']).columns.tolist()
        sns.set_palette("pastel")

    def plot_categorical_distribution(self):
        num_cat_vars = len(self.categorical_vars)
        num_rows = (num_cat_vars + 1) // 2  # Adjust number of rows
        num_cols = 2  # Fixed number of columns

        fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(18, 6 * num_rows))
        for ax, cat_var in zip(axes.flatten(), self.categorical_vars):
            sns.countplot(data=self.data, x=cat_var, ax=ax)
            ax.set_title(f'Distribution of {cat_var}\n')
            ax.set_ylabel('Count')
            ax.set_xlabel(cat_var)
            ax.tick_params(axis='x', rotation=45)
        plt.tight_layout()
        plt.show()

    def plot_continuous_distribution(self):
        num_cont_vars = len(self.continuous_vars)
        num_rows = (num_cont_vars + 2) // 3  # Adjust number of rows
        num_cols = 3  # Fixed number of columns

        fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(18, 6 * num_rows))
        for ax, cont_var in zip(axes.flatten(), self.continuous_vars):
            sns.histplot(data=self.data, x=cont_var, bins=20, kde=True, ax=ax)
            ax.set_title(f'Distribution of {cont_var}\n')
            ax.set_ylabel('Count')
            ax.set_xlabel(cont_var)
            ax.tick_params(axis='x', rotation=45)
        plt.tight_layout()
        plt.show()

# %%
# Create an instance of the UnivariateVisualizer class
visualizer = UnivariateVisualizer(analyzer.dataset)

# %%
# Plot continuous distribution
visualizer.plot_continuous_distribution()

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# Certainly! Let's focus on feature engineering techniques that are appropriate for your credit card fraud detection dataset:
#
# 1. **Time-Based Features:**
#    - Extract additional time-based features from the "Time" column, such as hour of the day, day of the week, or whether the transaction occurred during a weekend or a holiday.
#
# 2. **Transaction Amount Binning:**
#    - Bin the transaction amounts into categories or percentiles to capture different spending patterns.
#
# 3. **Normalization/Scaling:**
#    - Scale the "Amount" column to ensure that it has a similar scale to other numerical features. Common scaling methods include Min-Max scaling and Standardization (Z-score scaling).
#
# 4. **Log Transformation:**
#    - Apply a log transformation to highly skewed features to make their distribution more Gaussian-like. This can help linear models perform better.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Extract time-based features
df['hour_of_day'] = np.floor(df['Time'] / 3600) % 24
df['day_of_week'] = np.floor(df['Time'] / 86400) % 7

# Apply log transformation to Amount
df['log_amount'] = np.log1p(df['Amount'])

# Drop original "Time" and "Amount" columns
df.drop(['Time', 'Amount'], axis=1, inplace=True)

df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 283721 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 283722  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 283723   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 283724  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 283725  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V23       V24  \
# ...

# %%
# Separate features and target variable
X = df.drop(columns=['Class'])
y = df['Class']

# %% [markdown]
# # MODELLING

# %% [markdown]
# Check for class imbalance in the target variable

# %%
df.Class.value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# Handle Class Imbalance in the Target variable

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Assuming you have already loaded your data into X and y

# Apply SMOTE to address class imbalance
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %% [markdown]
# Split the data into training and testing sets

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %% [markdown]
# ### Model Evaluator
#
# The `ModelEvaluator` class is designed to evaluate and compare machine learning models. It includes methods to assess individual models, tune hyperparameters, and compare the performance of multiple models. Here's a breakdown of its main components:
#
# 1. **Initialization**:
#    - The class is initialized with training and testing data (`X_train`, `X_test`, `y_train`, `y_test`).
#    - It creates an empty dictionary, `self.models`, to store the best models.
#
# 2. **`evaluate_single_model` Method**:
#    - This method evaluates a single model and provides various performance metrics.
#    - It takes a machine learning model (`model`) and a `model_name` as input.
#    - The method calculates metrics such as AUC, accuracy, F1 score, precision, and recall.
#    - It generates ROC curves and a confusion matrix for visual assessment.
#    - The best model is stored in the `self.models` dictionary.
#
# 3. **`tune_model_with_gridsearch` Method**:
#    - This method tunes a model's hyperparameters using GridSearchCV.
#    - It takes the model to be tuned (`model`), a `model_name`, and a `param_grid` as input.
#    - GridSearchCV searches for the best hyperparameters within the given parameter grid.
#    - The best model is returned.
#
# 4. **`compare_models` Method**:
#    - This method compares the performance of multiple models and visualizes the results.
#    - It calculates AUC, F1 score, accuracy, precision, and recall for each model.
#    - The results are plotted on ROC curves.
#    - It also creates two bar graphs side by side: one for comparing F1 scores and the other for comparing accuracy scores.
#    - The method returns a DataFrame containing the performance metrics of all models.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, auc, roc_curve, classification_report, confusion_matrix

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

class ModelEvaluator:
    def __init__(self, X_train, X_test, y_train, y_test):
        self.X_train = X_train
        self.X_test = X_test
        self.y_train = y_train
        self.y_test = y_test
        
        # Create a dictionary to store the best models
        self.models = {}
        
    def evaluate_single_model(self, model, model_name):
        model.fit(self.X_train, self.y_train)
        y_prob = model.predict_proba(self.X_test)[:, 1]
        fpr, tpr, _ = roc_curve(self.y_test, y_prob)
        roc_auc = auc(fpr, tpr)
        y_pred = model.predict(self.X_test)
        accuracy = accuracy_score(self.y_test, y_pred)
        f1 = f1_score(self.y_test, y_pred)
        precision = precision_score(self.y_test, y_pred)
        recall = recall_score(self.y_test, y_pred)
        cm = confusion_matrix(self.y_test, y_pred)
        report = classification_report(self.y_test, y_pred)
        self.models[model_name] = model  # Update the best models in the dictionary

        metrics_df = pd.DataFrame({
            f"{model_name} Metrics": ['AUC', 'Accuracy', 'F1 Score', 'Precision', 'Recall'],
            'Value': [roc_auc, accuracy, f1, precision, recall]
        })

        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
        axes[0].plot(fpr, tpr, color='darkorange', lw=2,
                     label='ROC curve (area = {:.2f})'.format(roc_auc))
        axes[0].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        axes[0].set_xlim([0.0, 1.0])
        axes[0].set_ylim([0.0, 1.05])
        axes[0].set_xlabel('False Positive Rate')
        axes[0].set_ylabel('True Positive Rate')
        axes[0].set_title('Receiver Operating Characteristic (ROC) - {}'.format(model_name))
        axes[0].legend(loc='lower right')

        cm_rf = confusion_matrix(self.y_test, y_pred)
        ax = axes[1]
        sns.heatmap(cm_rf, annot=True, cmap='Oranges', fmt='g', ax=ax)
        ax.set_xlabel('Predicted Labels')
        ax.set_ylabel('True Labels')
        ax.set_title('Confusion Matrix - {}'.format(model_name))
        ax.xaxis.set_ticklabels(['0', '1'])
        ax.yaxis.set_ticklabels(['0', '1'])

        report_title = 'Classification Report - {}'.format(model_name)
        report_text = '\n'.join([f'    {line}' for line in report.split('\n')])
        plt.text(1.2, 0.5, report_title, fontsize=14, weight='bold', transform=plt.gcf().transFigure)
        plt.text(1.2, 0.4, report_text, fontsize=12, transform=plt.gcf().transFigure)

        plt.show()

        return metrics_df

    
    def tune_model_with_gridsearch(self, model, model_name, param_grid):
        grid_search = GridSearchCV(model, param_grid, cv=3, scoring='roc_auc',
                                   n_jobs=-1, verbose=1)
        grid_search.fit(self.X_train, self.y_train)
        best_model = grid_search.best_estimator_
        return best_model
    
    def compare_models(self):
        results = []

        plt.figure(figsize=(12, 6))  # Increase the figure size for better visualization
        plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Guess')

        f1_scores = []  # Store F1 scores for each model
        accuracy_scores = []  # Store accuracy scores for each model
        model_names = []  # Store model names for the x-axis

        for model_name, model in self.models.items():
            model.fit(self.X_train, self.y_train)
            y_prob = model.predict_proba(self.X_test)[:, 1]
            fpr, tpr, _ = roc_curve(self.y_test, y_prob)
            roc_auc = auc(fpr, tpr)
            y_pred = model.predict(self.X_test)
            f1 = f1_score(self.y_test, y_pred)
            accuracy = accuracy_score(self.y_test, y_pred)
            precision = precision_score(self.y_test, y_pred)
            recall = recall_score(self.y_test, y_pred)

            results.append({
                'Model': model_name,
                'AUC': roc_auc,
                'F1 Score': f1,
                'Accuracy': accuracy,
                'Precision': precision,
                'Recall': recall
            })

            f1_scores.append(f1)
            accuracy_scores.append(accuracy)
            model_names.append(model_name)

            plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) - All Models')
        plt.legend(loc='lower right')

        # Create subplots for F1 scores and accuracy scores side by side
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Bar graph for F1 scores
        axes[0].bar(model_names, f1_scores, color='skyblue')
        axes[0].set_xlabel('Model')
        axes[0].set_ylabel('F1 Score')
        axes[0].set_title('F1 Score Comparison')
        axes[0].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

        # Bar graph for accuracy scores
        axes[1].bar(model_names, accuracy_scores, color='lightcoral')
        axes[1].set_xlabel('Model')
        axes[1].set_ylabel('Accuracy Score')
        axes[1].set_title('Accuracy Score Comparison')
        axes[1].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

        plt.tight_layout()

        plt.show()

        results_df = pd.DataFrame(results).sort_values(by='F1 Score', ascending=False)

        return results_df




# Initialize Instance
evaluator = ModelEvaluator(X_train, X_test, y_train, y_test)

# %% [markdown]
# ### Logistic Regression
#
# **Approach:** Linear regression model used for binary classification by modeling the probability of belonging to a class.
#
# **Benefits:**
# - Simple and interpretable.
# - Efficient for large datasets.
# - Works well when the relationship is approximately linear.
#
# **Shortcomings:**
# - Assumes a linear relationship between features and log-odds.
# - May not perform well when data is not linearly separable.
# - Limited to binary classification by default.

# %%
from sklearn.linear_model import LogisticRegression

# Define parameter grid for Logistic Regression
logistic_param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']
}

# Tune and evaluate Logistic Regression
logistic_model = LogisticRegression()
best_logistic_model = evaluator.tune_model_with_gridsearch(logistic_model, 'LogisticRegression', logistic_param_grid)
evaluator.evaluate_single_model(best_logistic_model, 'LogisticRegression')
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#   LogisticRegression Metrics     Value
# 0                        AUC  0.989336
# 1                   Accuracy  0.947097
# 2                   F1 Score  0.945789
# 3                  Precision  0.973162
# 4                     Recall  0.919914

# %% [markdown]
# ### Decision Tree
#
# **Approach:** Non-linear supervised machine learning algorithm that partitions data into subsets based on feature conditions.
#
# **Benefits:**
# - Easy to understand and visualize.
# - Handles numerical and categorical data.
# - Can capture complex relationships.
#
# **Shortcomings:**
# - Prone to overfitting, especially with deep trees.
# - Sensitive to small variations in data.
# - Lack of robustness compared to ensemble methods.

# %%
from sklearn.tree import DecisionTreeClassifier
# Define parameter grid for Decision Tree
decision_tree_param_grid = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Tune and evaluate Decision Tree
decision_tree_model = DecisionTreeClassifier()
best_decision_tree_model = evaluator.tune_model_with_gridsearch(decision_tree_model, 'DecisionTree', decision_tree_param_grid)
evaluator.evaluate_single_model(best_decision_tree_model, 'DecisionTree')
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
#   DecisionTree Metrics     Value
# 0                  AUC  0.998855
# 1             Accuracy  0.998023
# 2             F1 Score  0.998030
# 3            Precision  0.997802
# 4               Recall  0.998258

# %% [markdown]
# # MODEL EVALUATION

# %%
# Compare models
model_results = evaluator.compare_models()
print(model_results)
# Out:
#                 Model       AUC  F1 Score  Accuracy  Precision    Recall
# 1        DecisionTree  0.998748  0.997863  0.997855   0.997679  0.998047
# 0  LogisticRegression  0.989336  0.945789  0.947097   0.973162  0.919914

# %% [markdown]
# These metrics provide insights into the models' performance:
#
# - **AUC**: AUC measures the area under the Receiver Operating Characteristic (ROC) curve. Both models have high AUC values, indicating strong discriminative power.
#
# - **F1 Score**: The F1 score is a harmonic mean of precision and recall. The DecisionTree model has a higher F1 score, indicating a good balance between precision and recall. The Logistic Regression model also has a reasonable F1 score.
#
# - **Accuracy**: Accuracy represents the proportion of correctly predicted instances. Both models have high accuracy values, indicating that they perform well in terms of overall correctness.
#
# - **Precision**: Precision measures the proportion of true positive predictions among all positive predictions. The Logistic Regression model has higher precision, suggesting it makes fewer false positive predictions.
#
# - **Recall**: Recall measures the proportion of true positive predictions among all actual positives. The DecisionTree model has higher recall, indicating that it captures more of the actual positive instances.
#
# In summary, the DecisionTree model appears to have better overall performance based on the F1 score, but the choice between models should depend on the specific requirements of the task. If minimizing false positives is critical, the Logistic Regression model with higher precision may be preferred. Conversely, if capturing more true positives is crucial, the DecisionTree model with higher recall may be a better choice.

# %% [markdown]
# # FINDINGS FROM OUR BEST MODEL

# %% [markdown]
# ### Feature Importance Visualization
#
# This code defines a function `plot_feature_importance` that visualizes the importance of features in a machine learning model, particularly useful for tree-based models like Decision Trees.
#
# - **Inputs:**
#   - `model`: The trained machine learning model.
#   - `feature_names`: A list of feature names used in the model.
#   - `top_n` (optional): Number of top features to display (default is 10).
#
# The function performs the following tasks:
# 1. Computes the feature importances from the model.
# 2. Identifies the indices of the top N most important features.
# 3. Retrieves the names and importance values of these top features.
# 4. Creates a horizontal bar plot to visualize the feature importances.
# 5. Displays the feature names on the y-axis and their importance values on the x-axis.
# 6. Inverts the y-axis to show the most important feature at the top.
# 7. Returns a DataFrame with feature names and their importance values in descending order.

# %%
import pandas as pd  # Add this import statement

def plot_feature_importance(model, feature_names, top_n=10):
    print(f"Feature names: {feature_names}")
    print(f"\nNumber of features: {top_n}")
    # Get feature importances from the model
    feature_importances = model.feature_importances_
    
    # Get the indices of the top N most important features
    top_feature_indices = feature_importances.argsort()[::-1][:top_n]
    
    # Get the feature names corresponding to the top indices
    top_feature_names = [feature_names[i] for i in top_feature_indices]
    
    # Get the feature importance values for the top features
    top_feature_importances = feature_importances[top_feature_indices]
    
    # Create a horizontal bar plot to visualize feature importances
    plt.figure(figsize=(10, 6))
    plt.barh(range(top_n), top_feature_importances, align='center')
    plt.yticks(range(top_n), top_feature_names)
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Name')
    plt.title('Top {} Most Important Features for {} model'.format(top_n, model.__class__.__name__))  # Corrected the title format
    plt.gca().invert_yaxis()  # Invert the y-axis to display the most important feature at the top
    plt.show()
    
    # Create a DataFrame with feature names and importance values
    feature_importance_df = pd.DataFrame({
        'Feature Name': top_feature_names,
        'Importance': top_feature_importances
    })

    return print(feature_importance_df)  # Return the DataFrame

# Usage:
# Assuming you have a trained DecisionTree model 'best_decision_tree_model' and a list of feature names 'feature_names'
feature_names = X.columns.tolist()
n = len(feature_names)

feature_importance_df = plot_feature_importance(best_decision_tree_model, feature_names, top_n=n)
# Out:
# Feature names: ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'hour_of_day', 'day_of_week', 'log_amount']
#
# Number of features: 31
#    Feature Name  Importance
# 0           V14    0.727908
# 1            V4    0.055316
# 2   day_of_week    0.034914
# 3           V12    0.017487
# 4            V8    0.016123
# 5            V1    0.014002
# 6           V13    0.012646
# 7           V10    0.011460
# 8            V7    0.009678
# 9            V3    0.009317
# 10   log_amount    0.009183
# 11           V9    0.009046
# 12          V15    0.008960
# 13          V18    0.007285
# 14  hour_of_day    0.007122
# 15          V23    0.005712
# 16          V26    0.004840
# 17          V17    0.004769
# 18          V25    0.004613
# 19          V11    0.004400
# 20          V19    0.004378
# 21           V6    0.003852
# 22           V2    0.002840
# ...

# %% [markdown]
# ### Findings
#
# 1. **Feature Importance Analysis**: The feature importance analysis reveals that the most influential feature in predicting fraudulent transactions is `V14`, followed by `V4` and `day_of_week`. These features have significantly higher importance values compared to others.
#
# 2. **Hour of the Day Impact**: The `hour_of_day` feature also plays a role in identifying fraud. While not as influential as some other features, it still contributes to the model's ability to detect fraudulent activities.
#
# 3. **Logarithm of Transaction Amount**: The `log_amount` feature, which represents the logarithm of the transaction amount, is among the top features. This suggests that monitoring transactions using the log of the amount can aid in fraud detection.

# %% [markdown]
# # RECOMMENDATIONS
#
# Based on the findings, here are some recommendations for improving fraud detection:
#
# 1. **Focus on Key Features**: Given the importance of features like `V14`, `V4`, and `day_of_week`, consider allocating more resources and attention to monitoring and analyzing transactions associated with these features.
#
# 2. **Real-time Monitoring**: Implement real-time transaction monitoring, especially during hours of the day when fraudulent activities are more likely to occur. This can enhance the system's ability to detect and prevent fraud as it happens.
#
# 3. **Advanced Modeling**: Explore more advanced machine learning models and techniques to further improve fraud detection accuracy. Ensemble methods and anomaly detection algorithms may be worth considering.
#
# 4. **Feature Engineering**: Continuously refine feature engineering by considering interactions between features and incorporating new features that may enhance fraud detection.
#
# # CONCLUSION
#
# In this project, we applied machine learning techniques to detect fraudulent credit card transactions. We evaluated multiple models, including Decision Trees, and analyzed feature importance to gain insights into the factors influencing fraud detection.
#
# The findings indicate that certain features, such as `V14`, `V4`, and `day_of_week`, have a significant impact on the model's ability to identify fraudulent transactions. Moreover, considering the hour of the day and using the logarithm of the transaction amount can contribute to better fraud detection.
#
# To enhance fraud detection, we recommend focusing on these key features, implementing real-time monitoring, exploring advanced modeling approaches, and continuously improving feature engineering. By doing so, we can further improve the accuracy and effectiveness of fraud detection systems, helping to protect both customers and financial institutions from fraudulent activities.
